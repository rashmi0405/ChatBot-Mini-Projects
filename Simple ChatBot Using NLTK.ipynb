# %% [markdown]
# ##Import necessary libraries

# %%
# !pip install nltk

# %%
import io
#Mount Google Drive
from google.colab import drive
import random
import string # to process standard python strings
import warnings
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import warnings
warnings.filterwarnings('ignore')
import nltk
from nltk.stem import WordNetLemmatizer
nltk.download('popular', quiet=True) # for downloading packages
# Out:
# True

# %% [markdown]
# ## Reading in the corpus

# %%
#Mount the Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#To get the path
# %cd /content/drive/My Drive/Colab Notebooks/New Projects 2024/
# Out:
# /content/drive/My Drive/Colab Notebooks/New Projects 2024

# %%
# !ls
# Out:
#  AI.txt  'Rule Based ChatBot.ipynb'  'Simple ChatBot Using NLTK.ipynb'

# %%
f=open('AI.txt','r',errors = 'ignore')
raw=f.read()
raw = raw.lower()# converts to lowercase

# %% [markdown]
# ## Tokenisation

# %%
sent_tokens = nltk.sent_tokenize(raw)# converts to list of sentences
word_tokens = nltk.word_tokenize(raw)# converts to list of words

# %% [markdown]
# ## Preprocessing

# %%
lemmer = nltk.stem.WordNetLemmatizer()
#WordNet is a semantically-oriented dictionary of English included in NLTK.
def LemTokens(tokens):
    return [lemmer.lemmatize(token) for token in tokens]
remove_punct_dict = dict((ord(punct), None) for punct in string.punctuation)

def LemNormalize(text):
    return LemTokens(nltk.word_tokenize(text.lower().translate(remove_punct_dict)))

# %% [markdown]
# ## Keyword matching

# %%
GREETING_INPUTS = ("hello", "hi", "greetings", "sup", "what's up","hey",)
GREETING_RESPONSES = ["hi", "hey", "*nods*", "hi there", "hello", "I am glad! You are talking to me"]
def greeting(sentence):

    for word in sentence.split():
        if word.lower() in GREETING_INPUTS:
            return random.choice(GREETING_RESPONSES)

# %% [markdown]
# ## Generating Response

# %%
def response(user_response):
    robo_response=''
    sent_tokens.append(user_response)
    TfidfVec = TfidfVectorizer(tokenizer=LemNormalize, stop_words='english')
    tfidf = TfidfVec.fit_transform(sent_tokens)
    vals = cosine_similarity(tfidf[-1], tfidf)
    idx=vals.argsort()[0][-2]
    flat = vals.flatten()
    flat.sort()
    req_tfidf = flat[-2]
    if(req_tfidf==0):
        robo_response=robo_response + "I am sorry! I don't understand you"
        return robo_response
    else:
        robo_response = robo_response+sent_tokens[idx]
        return robo_response

# %%
flag=True
print("SARA: My name is SARA. I will answer your queries about Generative AI. If you want to exit, type Bye!")
while(flag==True):
    user_response = input()
    user_response=user_response.lower()
    if(user_response!='bye'):
        if(user_response=='thanks' or user_response=='thank you' ):
            flag=False
            print("SARA: You are welcome..")
        else:
            if(greeting(user_response)!=None):
                print("SARA: "+greeting(user_response))
            else:
                print("SARA: ",end="")
                print(response(user_response))
                sent_tokens.remove(user_response)
    else:
        flag=False
        print("SARA: Bye! take care..")
# Out:
# SARA: My name is SARA. I will answer your queries about Generative AI. If you want to exit, type Bye!
# types
# SARA: I am sorry! I don't understand you
# ai
# SARA: here's a detailed description of generative ai:
#
# 1. overview:
# generative ai is a subset of artificial intelligence that focuses on the creation of new data rather than classification or prediction.
# go on
# SARA: I am sorry! I don't understand you
# hi there
# SARA: I am glad! You are talking to me
# hi
# SARA: I am glad! You are talking to me
# application
# SARA: 3. applications:
# generative ai finds applications in various domains, including:
#
# image generation: gans are commonly used to generate realistic images, whether it's faces, animals, or scenes.
# models
# SARA: 2. generative models:
# generative models are a class of machine learning models designed to generate new data samples that resemble a given training dataset.
# thanks
# SARA: You are welcome..
